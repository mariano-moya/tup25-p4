# %%
import re
from pathlib import Path


def leer(origen: str = "alumnos.md") -> list:
    """
    Lee un archivo markdown con datos de alumnos y devuelve una lista de diccionarios.
    """

    print(f"> Leyendo {origen}...")
    salida, comision = [], ""
    with open(origen, "r", encoding='utf-8') as archivo:
        for linea in archivo:
            if not linea.strip():
                continue

            if linea.startswith("##"):
                comision = "C" + linea.strip("# \n")[-1]

            if linea.startswith("- "):
                valores = re.split(r"\s{2,}", linea.strip("- \n"))
                if len(valores) == 3: valores.append("c")
                valores.append(comision)
                valores = dict(zip('legajo nombre telefono estado comision'.split(), valores))
                salida.append(valores)

    return sorted(salida, key=lambda x: [x['comision'], x['legajo']])


def escribir(alumnos, destino="alumnos2.md"):
    """ 
    Escribe un archivo markdown con datos de alumnos a partir de una lista de diccionarios.
    """

    print(f"> Escribiendo {destino}...")
    with open(destino, "w", encoding='utf-8') as archivo:
        archivo.write("# Programación 4 | TUP 25\n")
        for comision in sorted(set(alumno['comision'] for alumno in alumnos)):
            archivo.write(f"\n## Comisión {comision[-1]}\n\n")
            archivo.write("```text\n")
            for alumno in alumnos:
                if alumno['comision'] == comision:
                    archivo.write(f"- {alumno['legajo']}  {alumno['nombre']:40}  {alumno['telefono']}  {alumno['estado']}\n")
            archivo.write("```\n")
    return alumnos


def convertir_vcard(alumnos, archivo_destino="contactos_alumnos.vcf"):
    """
    Convierte una lista de alumnos en un archivo VCard compatible con WhatsApp.
    """

    print(f"> Generando archivo VCard: {archivo_destino}...")
    
    with open(archivo_destino, "w", encoding='utf-8') as archivo:
        for alumno in alumnos:
            # Separar nombre y apellidos
            nombre_completo = alumno['nombre'].strip()
            partes_nombre = nombre_completo.split(', ')
            
            if len(partes_nombre) == 2:
                # Formato: "Apellido, Nombre"
                apellidos = partes_nombre[0].strip()
                nombres = partes_nombre[1].strip()
            else:
                # Si no tiene el formato esperado, usar todo como nombre
                nombres = nombre_completo
                apellidos = ""
            
            # Limpiar el número de teléfono (remover espacios y caracteres especiales)
            telefono = re.sub(r'[^\d+]', '', alumno['telefono'])
            
            # Generar VCard
            vcard = [
                "BEGIN:VCARD",
                "VERSION:3.0",
                f"FN:{nombre_completo}",  # Nombre completo para mostrar
                f"N:{apellidos};{nombres};;;",  # Apellido;Nombre;SegundoNombre;Prefijo;Sufijo
                f"TEL;TYPE=CELL:{telefono}",  # Teléfono celular
                f"NOTE:Legajo: {alumno['legajo']} - Comision: P4-{alumno['comision']}",  # Nota con legajo y comisión
                "END:VCARD"
            ]
            
            # Escribir el VCard al archivo
            archivo.write("\n".join(vcard) + "\n\n")
    
    print(f"Archivo generado con {len(alumnos)} contactos.")
    return len(alumnos)


def normalizar(origen='alumnos.md', orden='nombre'):
    """ Lee un archivo markdown con datos de alumnos, los ordena y escribe en otro archivo.
        - orden: `nombre` | `legajo`
    """
    alumnos = leer(origen)
    alumnos = sorted(alumnos, key=lambda x: [x['comision'], x[orden]])
    return escribir(alumnos, origen)


def carpeta(alumno, tp=None): 
    """ Calcula el nombre de la carpeta para un alumno. """
    return f"../tp/{alumno['legajo']} - {alumno['nombre']}{'' if tp is None else f'/tp{tp}'}"


def crear_carpetas(alumnos):
    """Crea carpetas para cada alumno (tp/<legajo> - <nombre>) y un archivo info.txt dentro."""
    raiz = Path('tp')
    for a in alumnos:
        destino = Path(carpeta(a))  # ya incluye 'tp/...'
        # Si existe carpeta con nombre viejo (mismo legajo) renombrar
        for viejo in raiz.glob(f"{a['legajo']} -*"):
            if viejo != destino:
                viejo.rename(destino)
        # Asegurar existencia y escribir info.txt
        destino.mkdir(parents=True, exist_ok=True)
        (destino / "info.txt").write_text(
            f"Legajo: {a['legajo']}\nNombre: {a['nombre']}\nTeléfono: {a['telefono']}\nComisión: {a['comision']}\n",
            encoding='utf-8'
        )


normalizar()

# crear_carpetas(leer())
# Out:
# > Leyendo alumnos.md...
# > Escribiendo alumnos.md...
# [{'legajo': '61131',
#   'nombre': 'Agostino Colombres, Juan Manuel',
#   'telefono': '(381) 684-8399',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '62171',
#   'nombre': 'Ballespin, Cristian',
#   'telefono': '(381) 604-5734',
#   'estado': 'c',
#   'comision': 'C1'},
#  {'legajo': '99001',
#   'nombre': 'Branda, Cesar',
#   'telefono': '(381) 212-6932',
#   'estado': 'c',
#   'comision': 'C1'},
#  {'legajo': '61565',
#   'nombre': 'Carrizo, Mauro',
#   'telefono': '(381) 610-8745',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61551',
#   'nombre': 'Diaz Valdez, Ignacio',
#   'telefono': '(381) 695-8566',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61472',
#   'nombre': 'Diaz, Julieta Camila',
#   'telefono': '(381) 652-9981',
#   'estado': 'x',
#   'comision': 'C1'},
#  {'legajo': '61236',
#   'nombre': 'Drachenberg, Franco Eduardo',
#   'telefono': '(381) 670-8708',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61337',
#   'nombre': 'Díaz, Christian Gabriel',
#   'telefono': '(381) 571-4797',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61198',
#   'nombre': 'Ferreyra Appas, Santiago Nicolas',
#   'telefono': '(381) 648-4455',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61813',
#   'nombre': 'Figueroa, Manuel',
#   'telefono': '(381) 544-2423',
#   'estado': 'c',
#   'comision': 'C1'},
#  {'legajo': '61167',
#   'nombre': 'Giacobbe, Franco',
#   'telefono': '(381) 588-0371',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61073',
#   'nombre': 'Gonzalez Chavez, Rodrigo',
#   'telefono': '(381) 624-3000',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61463',
#   'nombre': 'Gonzalez, Vladimir',
#   'telefono': '(381) 419-4154',
#   'estado': 'x',
#   'comision': 'C1'},
#  {'legajo': '61120',
#   'nombre': 'Guerrero, Ana Sofía',
#   'telefono': '(381) 418-1564',
#   'estado': 'c',
#   'comision': 'C1'},
#  {'legajo': '54911',
#   'nombre': 'Jatib, Rodrigo Gabriel',
#   'telefono': '(381) 655-3096',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61805',
#   'nombre': 'Jerez, Tomás',
#   'telefono': '(381) 338-0186',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61035',
#   'nombre': 'Ledesma, Paulo Marcelo',
#   'telefono': '(381) 664-8356',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61115',
#   'nombre': 'Ledesma, Santiago Esteban',
#   'telefono': '(381) 346-3696',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61335',
#   'nombre': 'Leon, Lucas Ismael',
#   'telefono': '(381) 609-7898',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61911',
#   'nombre': 'Llanos, Luciano',
#   'telefono': '(381) 325-9224',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61993',
#   'nombre': 'Medina, Juan Ignacio',
#   'telefono': '(381) 517-1937',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61338',
#   'nombre': 'Morales, Juan Daniel',
#   'telefono': '(381) 665-5296',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '62263',
#   'nombre': 'Orellana, José Augusto',
#   'telefono': '(381) 339-2050',
#   'estado': 'c',
#   'comision': 'C1'},
#  {'legajo': '61046',
#   'nombre': 'Ponce, Luz Micaela',
#   'telefono': '(381) 664-7165',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '62318',
#   'nombre': 'Quiroga Castro, Lisandro',
#   'telefono': '(381) 390-9133',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61033',
#   'nombre': 'Quiroga, Jose Maria',
#   'telefono': '(11) 2399-7675',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '62175',
#   'nombre': 'Quiroga, Marcela Noemi Quiroga',
#   'telefono': '(381) 593-8430',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61084',
#   'nombre': 'Ramirez, Leonardo',
#   'telefono': '(381) 348-9132',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61315',
#   'nombre': 'Robles,Thiago',
#   'telefono': '(381) 567-4692',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61468',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'telefono': '(381) 679-6586',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61240',
#   'nombre': 'Timo, Hector Gabriel',
#   'telefono': '(381) 343-0992',
#   'estado': 'a',
#   'comision': 'C1'},
#  {'legajo': '61725',
#   'nombre': 'Villagra, Jorge Sebastián',
#   'telefono': '(381) 594-1635',
#   'estado': 'l',
#   'comision': 'C1'},
#  {'legajo': '61203',
#   'nombre': 'Acevedo Costello, Juan Ignacio',
#   'telefono': '(381) 388-7804',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61667',
#   'nombre': 'Acosta, Maira',
#   'telefono': '(381) 562-8162',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61719',
#   'nombre': 'Amoedo, Pablo Isaias',
#   'telefono': '(381) 463-6126',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '62055',
#   'nombre': 'Aumada, Aiquen Osvaldo',
#   'telefono': '(381) 419-9202',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61319',
#   'nombre': 'Carabajal, José Gabriel',
#   'telefono': '(381) 319-2680',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61214',
#   'nombre': 'Collazos Cortez, Maximo Alberto',
#   'telefono': '(381) 350-5275',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61141',
#   'nombre': 'Di Clemente, Maria Antonela',
#   'telefono': '(381) 398-3935',
#   'estado': 'l',
#   'comision': 'C3'},
#  {'legajo': '61626',
#   'nombre': 'Diaz Londero, Sergio Gonzalo',
#   'telefono': '(381) 604-6547',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61730',
#   'nombre': 'Diaz, Antonio',
#   'telefono': '(381) 392-6461',
#   'estado': 'c',
#   'comision': 'C3'},
#  {'legajo': '61271',
#   'nombre': 'Donelli, Gerardo Exequiel',
#   'telefono': '(381) 514-3223',
#   'estado': 'l',
#   'comision': 'C3'},
#  {'legajo': '61221',
#   'nombre': 'Duclós, Marcelo Ezequiel',
#   'telefono': '(381) 551-4353',
#   'estado': 'l',
#   'comision': 'C3'},
#  {'legajo': '61720',
#   'nombre': 'Fernandez, Luciano',
#   'telefono': '(381) 586-7891',
#   'estado': 'c',
#   'comision': 'C3'},
#  {'legajo': '62093',
#   'nombre': 'Frias Silva, Juan Segundo',
#   'telefono': '(381) 415-8753',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61139',
#   'nombre': 'Gallo, María Matilde',
#   'telefono': '(381) 333-4836',
#   'estado': 'l',
#   'comision': 'C3'},
#  {'legajo': '61352',
#   'nombre': 'García Moya, José Ignacio',
#   'telefono': '(381) 638-9006',
#   'estado': 'c',
#   'comision': 'C3'},
#  {'legajo': '61200',
#   'nombre': 'Gauna Serrano, Martin Javier',
#   'telefono': '(381) 389-2631',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61624',
#   'nombre': 'Godoy, Alan',
#   'telefono': '(381) 574-4877',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61595',
#   'nombre': 'Gonzalez Patti, Valentin',
#   'telefono': '(381) 655-9195',
#   'estado': 'c',
#   'comision': 'C3'},
#  {'legajo': '61579',
#   'nombre': 'Gonzalo, Marti',
#   'telefono': '(381) 418-6882',
#   'estado': 'c',
#   'comision': 'C3'},
#  {'legajo': '61562',
#   'nombre': 'Helguera, Agustina Elizabeth',
#   'telefono': '(381) 694-9619',
#   'estado': 'c',
#   'comision': 'C3'},
#  {'legajo': '62053',
#   'nombre': 'Herrera Palomino, Ivan Agustín',
#   'telefono': '(381) 697-0643',
#   'estado': 'l',
#   'comision': 'C3'},
#  {'legajo': '61450',
#   'nombre': 'Jimenez Paz, Patricio Agustín',
#   'telefono': '(381) 388-2674',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61627',
#   'nombre': 'Juarez Fernandez, Lourdes Abril',
#   'telefono': '(381) 647-9914',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61473',
#   'nombre': 'Lagoria Garcia, Tomás Gustavo',
#   'telefono': '(381) 357-7724',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61956',
#   'nombre': 'Leglise, Laureano',
#   'telefono': '(261) 468-9809',
#   'estado': 'c',
#   'comision': 'C3'},
#  {'legajo': '61679',
#   'nombre': 'Lobo Barrera, Mia de los Angeles',
#   'telefono': '(381) 677-0639',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61794',
#   'nombre': 'Lobo Campero, Hernán Ignacio',
#   'telefono': '(381) 590-6461',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61818',
#   'nombre': 'Lopez, Tisera Gaston',
#   'telefono': '(381) 523-5887',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '62172',
#   'nombre': 'Mariana Aylen Salcedo',
#   'telefono': '(381) 466-9695',
#   'estado': 'c',
#   'comision': 'C3'},
#  {'legajo': '61445',
#   'nombre': 'Martínez Campero, Santiago',
#   'telefono': '(381) 646-6685',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61676',
#   'nombre': 'Massey, Maximiliano',
#   'telefono': '(381) 359-9941',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61150',
#   'nombre': 'Molina Navarro, Juan Martin',
#   'telefono': '(381) 644-3413',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61032',
#   'nombre': 'Moya, Mariano',
#   'telefono': '(381) 670-1164',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61581',
#   'nombre': 'Naim, Federico Paz',
#   'telefono': '(381) 353-0060',
#   'estado': 'c',
#   'comision': 'C3'},
#  {'legajo': '62263',
#   'nombre': 'Orellana, José Augusto',
#   'telefono': '(386) 534-2925',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61113',
#   'nombre': 'Oríz Caballero, Juan José',
#   'telefono': '(381) 631-7223',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61059',
#   'nombre': 'Palavecino, Fabricio Gaston',
#   'telefono': '(381) 666-6103',
#   'estado': 'c',
#   'comision': 'C3'},
#  {'legajo': '61248',
#   'nombre': 'Palma Collado, Nahuel',
#   'telefono': '(381) 674-7012',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61572',
#   'nombre': 'Parrado Navarrete, Alex Daniel',
#   'telefono': '(381) 409-5039',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61312',
#   'nombre': 'Paz Berrondo, Lucas David',
#   'telefono': '(381) 341-4321',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61037',
#   'nombre': 'Paz, Rodrigo Federico',
#   'telefono': '(381) 637-6461',
#   'estado': 'l',
#   'comision': 'C3'},
#  {'legajo': '61028',
#   'nombre': 'Ponce, Rodrigo Exequiel',
#   'telefono': '(381) 569-0318',
#   'estado': 'l',
#   'comision': 'C3'},
#  {'legajo': '61197',
#   'nombre': 'Romano, Alfredo Nicolás',
#   'telefono': '(381) 648-8513',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61136',
#   'nombre': 'Sosa, Oscar Ignacio',
#   'telefono': '(381) 528-9145',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61478',
#   'nombre': 'Soto, Antonella',
#   'telefono': '(387) 517-0010',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61096',
#   'nombre': 'Suárez Vece, Leandro Andrés',
#   'telefono': '(381) 512-6476',
#   'estado': 'l',
#   'comision': 'C3'},
#  {'legajo': '61129',
#   'nombre': 'Tello, Abril María Agosti',
#   'telefono': '(381) 447-2483',
#   'estado': 'l',
#   'comision': 'C3'},
#  {'legajo': '61793',
#   'nombre': 'Trujillo, Facundo Nahuel',
#   'telefono': '(381) 206-2084',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '62555',
#   'nombre': 'Verón, Matias Gabriel',
#   'telefono': '(381) 519-6654',
#   'estado': 'a',
#   'comision': 'C3'},
#  {'legajo': '61862',
#   'nombre': 'Zerda, Thomas',
#   'telefono': '(381) 333-0962',
#   'estado': 'c',
#   'comision': 'C3'}]

# %%
import shutil
from pathlib import Path

def copiar_tp(tp=1, alumnos=None):
    """ Copia todos los archivos y subcarpetas de enunciados/tp{tp}
        a la carpeta correspondiente de cada alumno (tp/<legajo> - <nombre>/tp{tp}).
    """
    if alumnos is None:
        alumnos = leer()

    origen_base = Path(f"../enunciados/tp{tp}")
    if not origen_base.exists():
        print(f"No existe {origen_base}")
        return

    for a in alumnos:
        destino_base = Path(carpeta(alumno=a, tp=tp))  # ya incluye 'tp/.../tp{tp}'
        destino_base.mkdir(parents=True, exist_ok=True)

        print(f"\n==> Copiando en {destino_base}")

        for origen in origen_base.rglob('*'):
            rel = origen.relative_to(origen_base)
            destino = destino_base / rel

            destino.parent.mkdir(parents=True, exist_ok=True)
            shutil.copy2(origen, destino)
            print(f"Copiado: {origen} -> {destino}")


alumnos = leer()
crear_carpetas(alumnos)
copiar_tp(1, alumnos)
# Out:
# > Leyendo alumnos.md...
#
# ==> Copiando en ../tp/54911 - Jatib, Rodrigo Gabriel/tp1
# Copiado: ../enunciados/tp1/io.js -> ../tp/54911 - Jatib, Rodrigo Gabriel/tp1/io.js
# Copiado: ../enunciados/tp1/enunciado.md -> ../tp/54911 - Jatib, Rodrigo Gabriel/tp1/enunciado.md
# Copiado: ../enunciados/tp1/agenda.json -> ../tp/54911 - Jatib, Rodrigo Gabriel/tp1/agenda.json
# Copiado: ../enunciados/tp1/ejercicio.js -> ../tp/54911 - Jatib, Rodrigo Gabriel/tp1/ejercicio.js
#
# ==> Copiando en ../tp/61033 - Quiroga, Jose Maria/tp1
# Copiado: ../enunciados/tp1/io.js -> ../tp/61033 - Quiroga, Jose Maria/tp1/io.js
# Copiado: ../enunciados/tp1/enunciado.md -> ../tp/61033 - Quiroga, Jose Maria/tp1/enunciado.md
# Copiado: ../enunciados/tp1/agenda.json -> ../tp/61033 - Quiroga, Jose Maria/tp1/agenda.json
# Copiado: ../enunciados/tp1/ejercicio.js -> ../tp/61033 - Quiroga, Jose Maria/tp1/ejercicio.js
#
# ==> Copiando en ../tp/61035 - Ledesma, Paulo Marcelo/tp1
# Copiado: ../enunciados/tp1/io.js -> ../tp/61035 - Ledesma, Paulo Marcelo/tp1/io.js
# Copiado: ../enunciados/tp1/enunciado.md -> ../tp/61035 - Ledesma, Paulo Marcelo/tp1/enunciado.md
# Copiado: ../enunciados/tp1/agenda.json -> ../tp/61035 - Ledesma, Paulo Marcelo/tp1/agenda.json
# Copiado: ../enunciados/tp1/ejercicio.js -> ../tp/61035 - Ledesma, Paulo Marcelo/tp1/ejercicio.js
#
# ==> Copiando en ../tp/61046 - Ponce, Luz Micaela/tp1
# Copiado: ../enunciados/tp1/io.js -> ../tp/61046 - Ponce, Luz Micaela/tp1/io.js
# Copiado: ../enunciados/tp1/enunciado.md -> ../tp/61046 - Ponce, Luz Micaela/tp1/enunciado.md
# Copiado: ../enunciados/tp1/agenda.json -> ../tp/61046 - Ponce, Luz Micaela/tp1/agenda.json
# Copiado: ../enunciados/tp1/ejercicio.js -> ../tp/61046 - Ponce, Luz Micaela/tp1/ejercicio.js
#
# ==> Copiando en ../tp/61073 - Gonzalez Chavez, Rodrigo/tp1
# Copiado: ../enunciados/tp1/io.js -> ../tp/61073 - Gonzalez Chavez, Rodrigo/tp1/io.js
# Copiado: ../enunciados/tp1/enunciado.md -> ../tp/61073 - Gonzalez Chavez, Rodrigo/tp1/enunciado.md
# Copiado: ../enunciados/tp1/agenda.json -> ../tp/61073 - Gonzalez Chavez, Rodrigo/tp1/agenda.json
# Copiado: ../enunciados/tp1/ejercicio.js -> ../tp/
tp1/io.js
# Copiado: ../enunciados/tp1/enunciado.md -> ../tp/62053 - Herrera Palomino, Ivan Agustín/tp1/enunciado.md
# Copiado: ../enunciados/tp1/agenda.json -> ../tp/62053 - Herrera Palomino, Ivan Agustín/tp1/agenda.json
# Copiado: ../enunciados/tp1/ejercicio.js -> ../tp/62053 - Herrera Palomino, Ivan Agustín/tp1/ejercicio.js
#
# ==> Copiando en ../tp/62055 - Aumada, Aiquen Osvaldo/tp1
# Copiado: ../enunciados/tp1/io.js -> ../tp/62055 - Aumada, Aiquen Osvaldo/tp1/io.js
# Copiado: ../enunciados/tp1/enunciado.md -> ../tp/62055 - Aumada, Aiquen Osvaldo/tp1/enunciado.md
# Copiado: ../enunciados/tp1/agenda.json -> ../tp/62055 - Aumada, Aiquen Osvaldo/tp1/agenda.json
# Copiado: ../enunciados/tp1/ejercicio.js -> ../tp/62055 - Aumada, Aiquen Osvaldo/tp1/ejercicio.js
#
# ==> Copiando en ../tp/62093 - Frias Silva, Juan Segundo/tp1
# Copiado: ../enunciados/tp1/io.js -> ../tp/62093 - Frias Silva, Juan Segundo/tp1/io.js
# Copiado: ../enunciados/tp1/enunciado.md -> ../tp/62093 - Frias Silva, Juan Segundo/tp1/enunciado.md
# Copiado: ../enunciados/tp1/agenda.json -> ../tp/62093 - Frias Silva, Juan Segundo/tp1/agenda.json
# Copiado: ../enunciados/tp1/ejercicio.js -> ../tp/62093 - Frias Silva, Juan Segundo/tp1/ejercicio.js
#
# ==> Copiando en ../tp/62172 - Mariana Aylen Salcedo/tp1
# Copiado: ../enunciados/tp1/io.js -> ../tp/62172 - Mariana Aylen Salcedo/tp1/io.js
# Copiado: ../enunciados/tp1/enunciado.md -> ../tp/62172 - Mariana Aylen Salcedo/tp1/enunciado.md
# Copiado: ../enunciados/tp1/agenda.json -> ../tp/62172 - Mariana Aylen Salcedo/tp1/agenda.json
# Copiado: ../enunciados/tp1/ejercicio.js -> ../tp/62172 - Mariana Aylen Salcedo/tp1/ejercicio.js
#
# ==> Copiando en ../tp/62263 - Orellana, José Augusto/tp1
# Copiado: ../enunciados/tp1/io.js -> ../tp/62263 - Orellana, José Augusto/tp1/io.js
# Copiado: ../enunciados/tp1/enunciado.md -> ../tp/62263 - Orellana, José Augusto/tp1/enunciado.md
# Copiado: ../enunciados/tp1/agenda.json -> ../tp/62263 - Orellana, José Augusto/tp1/agenda.json
# Copiado: ../enunciados/tp1/ejercicio.js -> ../tp/62263 - Orellana, José Augusto/tp1/ejercicio.js
#
# ==> Copiando en ../tp/62555 - Verón, Matias Gabriel/tp1
# Copiado: ../enunciados/tp1/io.js -> ../tp/62555 - Verón, Matias Gabriel/tp1/io.js
# Copiado: ../enunciados/tp1/enunciado.md -> ../tp/62555 - Verón, Matias Gabriel/tp1/enunciado.md
# Copiado: ../enunciados/tp1/agenda.json -> ../tp/62555 - Verón, Matias Gabriel/tp1/agenda.json
# Copiado: ../enunciados/tp1/ejercicio.js -> ../tp/62555 - Verón, Matias Gabriel/tp1/ejercicio.js

# %%
# Ejemplo de uso de la función convertir_vcard
alumnos = leer('alumnos.md')
print(f"Se encontraron {len(alumnos)} alumnos")

# Generar archivo VCard con todos los alumnos
contactos_generados = convertir_vcard(alumnos, "alumnos.vcf")

print("Archivos VCard generados exitosamente!")
print("Puedes importar estos archivos directamente en WhatsApp o en tu aplicación de contactos.")
# Out:
# > Leyendo alumnos.md...
# Se encontraron 82 alumnos
# > Generando archivo VCard: alumnos.vcf...
# Archivo generado con 82 contactos.
# Archivos VCard generados exitosamente!
# Puedes importar estos archivos directamente en WhatsApp o en tu aplicación de contactos.

# %%
# import pandas as pd
# p = "./alumnos.csv"


# # Leer como cadenas (evita problemas con tipos mixtos), manejar comillas internas y espacios
# c = pd.read_csv(p, dtype=str, encoding="utf-8", skipinitialspace=True, keep_default_na=False)
# a = pd.DataFrame(leer())

# c['legajo'] = c['legajo'].astype(str).str.strip()
# a['legajo'] = a['legajo'].astype(str).str.strip()

# faltantes = c[~c['legajo'].isin(a['legajo'])]
# faltantes.to_csv("alumnos_faltantes(c-a).csv", index=False, encoding="utf-8")
# faltantes = a[~a['legajo'].isin(c['legajo'])]
# faltantes.to_csv("alumnos_faltantes(a-c).csv", index=False, encoding="utf-8")
# a.to_csv("alumnos_a.csv", index=False, encoding="utf-8")
# c.to_csv("alumnos_c.csv", index=False, encoding="utf-8")
